# %% [markdown]
# # **Project 1: Portfolio Analysis Project Copy**

# %% [markdown]
# Group Members:
# 1. Saanavi Goyal
# 2. Vanessa Campos
# 3. Jannat Nabonee

# %% [markdown]
# *Primary Objective:* Create a portfolio of seven (7) NSYE traded assets. Complete all the steps below and return the
# risk analysis of your seven (7) stock portfolio against the S&P500 (SPY), Russell 2000 (IWM), and the Dow Jones
# Industrial Average (DIA).

# %% [markdown]
# 7 NYSE Traded Assets:
#   1. Johnson & Johnson
#   2. Coca-cola
#   3. The Walt Disney Company
#   4. AT&T
#   5. Boeing
#   6. CVS Health Corporation
#   7. United Parcel Service

# %%
pip install yfinance

# %%
#retrrieve NYSE financial data using the yahoo finance library
import yfinance as yf

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#create a list of tickers
tickers = ['BA', 'CVS', 'DIS', 'JNJ', 'KO', 'T', 'UPS']

#getting the data for the tickers for 10 years
start_date = pd.to_datetime('2014-09-29')
end_date = pd.to_datetime('2024-09-27')
ticker_data = yf.download(tickers, start=start_date, end=end_date)['Close']
# Out:
# [*********************100%***********************]  7 of 7 completed

# %%
ticker_data
# Out:
# Ticker                             BA        CVS        DIS         JNJ  \
# Date
# 2014-09-29 00:00:00+00:00  128.770004  80.029999  88.830002  106.540001
# 2014-09-30 00:00:00+00:00  127.379997  79.589996  89.029999  106.589996
# 2014-10-01 00:00:00+00:00  124.669998  79.139999  87.489998  104.300003
# 2014-10-02 00:00:00+00:00  124.169998  80.059998  86.790001  103.849998
# 2014-10-03 00:00:00+00:00  126.360001  81.330002  88.449997  105.129997
# ...                               ...        ...        ...         ...
# 2024-09-20 00:00:00+00:00  153.289993  57.509998  93.750000  164.160004
# 2024-09-23 00:00:00+00:00  156.300003  57.570000  92.970001  163.220001
# 2024-09-24 00:00:00+00:00  155.809998  58.080002  93.690002  162.779999
# 2024-09-25 00:00:00+00:00  152.220001  58.639999  93.919998  160.600006
# 2024-09-26 00:00:00+00:00  154.580002  59.009998  95.199997  161.389999
#
# Ticker                            KO          T         UPS
# Date
# ...

# %%
#graphs to show the price history for each data
for ticker in tickers:
    plt.figure(figsize=(12, 8))
    plt.plot(ticker_data[ticker], label=ticker)
    plt.title(f"{ticker} Price History")
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# %%
#get the historical benchmark data
benchmark = ['SPY', 'IWM', 'DIA']
start_date = pd.to_datetime('2014-09-29')
end_date = pd.to_datetime('2024-09-27')
benchmark_data = yf.download(benchmark, start=start_date, end=end_date)['Close']
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
benchmark_data
# Out:
# Ticker                            DIA         IWM         SPY
# Date
# 2014-09-29 00:00:00+00:00  170.330002  111.029999  197.539993
# 2014-09-30 00:00:00+00:00  170.070007  109.349998  197.020004
# 2014-10-01 00:00:00+00:00  167.679993  107.800003  194.350006
# 2014-10-02 00:00:00+00:00  167.649994  108.830002  194.380005
# 2014-10-03 00:00:00+00:00  169.720001  109.650002  196.520004
# ...                               ...         ...         ...
# 2024-09-20 00:00:00+00:00  420.570007  221.570007  568.250000
# 2024-09-23 00:00:00+00:00  421.109985  220.759995  569.669983
# 2024-09-24 00:00:00+00:00  422.130005  221.130005  571.299988
# 2024-09-25 00:00:00+00:00  419.119995  217.690002  570.039978
# 2024-09-26 00:00:00+00:00  421.619995  218.850006  572.299988
#
# [2516 rows x 3 columns]

# %%
#graphs to show the price history for each data
for b in benchmark:
    plt.figure(figsize=(12, 8))
    plt.plot(benchmark_data[b], label=b)
    plt.title(f"{b} Benchmark Price History")
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# %%
#check if the data has any missing data values for ticker data
ticker_data.isnull().sum()
# Out:
# Ticker
# BA     0
# CVS    0
# DIS    0
# JNJ    0
# KO     0
# T      0
# UPS    0
# dtype: int64

# %%
ticker_data[ticker_data.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [BA, CVS, DIS, JNJ, KO, T, UPS]
# Index: []

# %%
#check if the data has any missing data values for benchmark data
benchmark_data.isnull().sum()
# Out:
# Ticker
# DIA    0
# IWM    0
# SPY    0
# dtype: int64

# %%
benchmark_data[benchmark_data.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [DIA, IWM, SPY]
# Index: []

# %% [markdown]
# Annualized Volatility = σ x 252
# 1. Find the daily returns for stock and benchmark (and weekly)
# 2. Use weights - 1/7 for each portfolio

# %%
#annualized volatility for trailing three months
volatility = ticker_data.rolling(window=63).std()*np.sqrt(252)
annualized_volatility = volatility.iloc[-1]

# %%
#Reset index
benchmark_data = benchmark_data.reset_index()

# %%
#Ensure equal-weighted portfolio
weights = np.ones(len(tickers))/len(tickers)

# %%
#Calculate beta against SPY, IWM, and DIA (using trailing 12-months)
betas = []
for i, ticker in enumerate(tickers):
  benchmark = benchmark_data.loc[benchmark_data['Date'].apply(lambda x: x.strftime('%Y-%m-%d'))==ticker,:]
  if not benchmark.empty:
    returns = data[ticker].pct_change()
    benchmark_returns = benchmark['Close'].pct_change
    covariance = np.cov(returns, benchmark_returns, ddof=0)
    variance = np.var(returns, ddof=0)
    beta = covariance[0,1]/variance
    betas.append(beta)
  else:
      betas.append(np.nan)

spy_beta = next ((b for b, t in zip(betas, tickers) if t == 'SPY'), np.nan)
iwm_beta = next ((b for b, t in zip(betas, tickers) if t == 'IWM'), np.nan)
dia_beta = next ((b for b, t in zip(betas, tickers) if t == 'DIA'), np.nan)

# %%
#Determine average and maximum weekly drawdowns

weekly_returns = ticker_data.pct_change().rolling(window=5).mean()
max_prices = ticker_data.rolling(window=52).max()
min_prices = ticker_data.rolling(window=52).min()
drawdowns = (max_prices - ticker_data) / max_prices
avg_wkly_drawdown = drawdowns.rolling(window=5).mean().iloc[-1]
max_wkly_drawdown = drawdowns.rolling(window=52).min().iloc[-1]

# %%
#Calculate Total Return and Annualized Total Return (using trailing 10-years)
total_return = (ticker_data.iloc[-1] / ticker_data.iloc[0])-1
annual_total_return = (1 + total_return) ** (252/len(ticker_data))-1

# %%
#Create risk analysis table as of current date
#Column 1 - Ticker
#Column 2 - Portfolio Weight (equally weighted)
#Column 3 - Annualized Volatility (using trailing 3-months)
#Column 4 - Beta against SPY (using trailing 12-months)
#Column 5 - Beta against IWM (using trailing 12-months)
#Column 6 - Beta against DIA (using trailing 12-months)
#Column 7 - Average Weekly Drawdown (52-week Low minus 52-week High) / 52-week High
#Column 8 - Maximum Weekly Drawdown (52-week Low minus 52-week High) / 52-week High
#Column 9 - Total Return (using trailing 10-years)
#Column 10 - Annualized Total Return (using trailing 10-years)


#Create the risk analysis table
risk_analysis = pd.DataFrame({
    'Ticker': tickers,
    'Portfolio Weight': weights,
    'Annualized Volatility': annualized_volatility,
    'Beta Against SPY': spy_beta,
    'Beta Against IWM': iwm_beta,
    'Beta Against DIA': dia_beta,
    'Average Weekly Drawdown': avg_wkly_drawdown,
    'Maximum Weekly Drawdown': max_wkly_drawdown,
    'Total Return': total_return,
    'Annualized Total Return': annual_total_return
})


#Display risk analysis table
risk_analysis
# Out:
#        Ticker  Portfolio Weight  Annualized Volatility  Beta Against SPY  \
# Ticker
# BA         BA          0.142857             177.788679               NaN
# CVS       CVS          0.142857              22.344108               NaN
# DIS       DIS          0.142857              60.565141               NaN
# JNJ       JNJ          0.142857             103.624492               NaN
# KO         KO          0.142857              50.888852               NaN
# T           T          0.142857              17.391015               NaN
# UPS       UPS          0.142857              93.798928               NaN
#
#         Beta Against IWM  Beta Against DIA  Average Weekly Drawdown  \
# Ticker
# BA                   NaN               NaN                 0.189717
# CVS                  NaN               NaN                 0.079424
# DIS                  NaN               NaN                 0.046349
# JNJ                  NaN               NaN                 0.029573
# ...

# %%
#create a list of ETFs
etfs = ['SPY','IWM', 'HDV']

#getting the data for ETFs for 10 years
etf_data = yf.download(etfs, period = '10y', interval = '1d')
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
#Create variable for ETF returns and calculate returns
returns = etf_data['Adj Close'].pct_change().dropna()

# %%
#Calculate correlation matrix
corr_matrix = returns.corr()
corr_matrix
# Out:
# Ticker       HDV       IWM       SPY
# Ticker
# HDV     1.000000 -0.003724 -0.024085
# IWM    -0.003724  1.000000  0.001148
# SPY    -0.024085  0.001148  1.000000

# %%
import seaborn as sns

# %%
#plot correlation matrix
plt.figure(figsize=(8, 4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix of ETF Returns', fontsize=14)
plt.show()

# %%
#Calculate the covariance of the matrix
covar_matrix = returns.cov()
covariance_with_etf =returns.cov()
covar_matrix
# Out:
# Ticker       HDV       IWM       SPY
# Ticker
# HDV     0.000100  0.000107  0.000095
# IWM     0.000107  0.000200  0.000136
# SPY     0.000095  0.000136  0.000124

# %%
covariance_with_etf
# Out:
# Ticker       HDV       IWM       SPY
# Ticker
# HDV     0.000100  0.000107  0.000095
# IWM     0.000107  0.000200  0.000136
# SPY     0.000095  0.000136  0.000124

# %%
print(returns.head())
print(returns.shape)  # It should return (n, m), where n is the number of rows and m is the number of ETFs (should be >= 2)
# Out:
# Ticker                          HDV       IWM       SPY
# Date
# 2014-10-02 00:00:00+00:00 -0.001073  0.009555  0.000155
# 2014-10-03 00:00:00+00:00  0.008728  0.007535  0.011010
# 2014-10-06 00:00:00+00:00  0.000665 -0.008573 -0.001170
# 2014-10-07 00:00:00+00:00 -0.010775 -0.016466 -0.015437
# 2014-10-08 00:00:00+00:00  0.016272  0.019173  0.017490
# (2515, 3)

# %%
#plot the covariance graph
plt.figure(figsize=(8, 4))
sns.heatmap(covariance_with_etf, annot=True, cmap='coolwarm', fmt='.6f', linewidths=0.5)
plt.title('Covariance Matrix of ETF Returns', fontsize=14)
plt.xlabel('ETF Tickers', fontsize=12)
plt.ylabel('ETF Tickers', fontsize=12)
plt.show()

# %%
#standard deviation between portfolios and ETFs
etf_std = returns.std() * np.sqrt(252)
etf_std
# Out:
# Ticker
# HDV    0.158880
# IWM    0.224367
# SPY    0.176428
# dtype: float64

# %%
#Identify tracking errors (using trailing 10-years)
tracking_errors = (returns.subtract(returns['SPY'], axis=0)).abs().mean()
tracking_errors
# Out:
# Ticker
# HDV    0.004199
# IWM    0.005277
# SPY    0.000000
# dtype: float64

# %%
#Calculate Sharpe Ration (using current risk-free rate)
risk_free_rate = 0
sharpe_ratio = (returns.mean() - risk_free_rate) / returns.std()
sharpe_ratio
# Out:
# Ticker
# HDV    0.037743
# IWM    0.031055
# SPY    0.050628
# dtype: float64

# %%
# Calculate annualized volatility
annualized_volatility = returns.std() * np.sqrt(252)
annualized_volatility
# Out:
# Ticker
# HDV    0.158880
# IWM    0.224367
# SPY    0.176428
# dtype: float64

# %%
# Annualized volatility spread against SPY
volatility_spread = (annualized_volatility - annualized_volatility['SPY']).abs()
volatility_spread
# Out:
# Ticker
# HDV    0.017548
# IWM    0.047939
# SPY    0.000000
# dtype: float64

# %%
#Create a table showing Portfolio Risk against the three EFTs:
#Column 1 - ETF Ticker
#Column 2 - Correlation against ETF
#Column 3 - Covariance of Portfolio against ETF
#Column 4 - Tracking Errors (using trailing 10-years)
#Column 5 - Standard Deviation
#Column 6 - Sharpe Ratio (using current risk-free rate)
#Column 7 - Annualized Volatility (252 days) Spread (Portfolio Volatility - ETF Volatility)

portfolio_risk = pd.DataFrame({
    'ETF Ticker': etfs,
    'Correlation Against ETF': corr_matrix.loc['SPY', etfs],
    'Covariance Against ETF': covar_matrix.loc['SPY', etfs],
    'Standard Deviation ETF':  etf_std[etfs],
    'Tracking Errors': tracking_errors[etfs],
    'Sharpe Ratio': sharpe_ratio[etfs],
    'Annualized Volatility Spread': volatility_spread[etfs]
})


portfolio_risk
# Out:
#        ETF Ticker  Correlation Against ETF  Covariance Against ETF  \
# Ticker
# SPY           SPY                 1.000000                0.000124
# IWM           IWM                 0.001148                0.000136
# HDV           HDV                -0.024085                0.000095
#
#         Standard Deviation ETF  Tracking Errors  Sharpe Ratio  \
# Ticker
# SPY                   0.176428         0.000000      0.050628
# IWM                   0.224367         0.005277      0.031055
# HDV                   0.158880         0.004199      0.037743
#
#         Annualized Volatility Spread
# Ticker
# SPY                         0.000000
# IWM                         0.047939
# HDV                         0.017548

# %%
#correlation matrices

returns = returns.pct_change().dropna()

corr_matrix = returns.corr()

equal_weight_corr = returns.mean

plt

equal_weight_corr
# Out:
# <bound method DataFrame.mean of Ticker                           HDV       IWM        SPY
# Date
# 2014-10-03 00:00:00+00:00  -9.133797 -0.211417  70.249596
# 2014-10-06 00:00:00+00:00  -0.923768 -2.137794  -1.106314
# 2014-10-07 00:00:00+00:00 -17.194692  0.920672  12.188328
# 2014-10-08 00:00:00+00:00  -2.510130 -2.164432  -2.133000
# 2014-10-09 00:00:00+00:00  -2.049030 -2.407170  -2.134009
# ...                              ...       ...        ...
# 2024-09-24 00:00:00+00:00  -1.248479 -1.458485   0.145043
# 2024-09-25 00:00:00+00:00   4.571791 -8.277123  -1.770804
# 2024-09-26 00:00:00+00:00  -0.725225 -1.436877  -2.797609
# 2024-09-27 00:00:00+00:00  -4.712259  0.269092  -1.365812
# 2024-09-30 00:00:00+00:00  -0.474520 -0.624164  -3.763034
#
# [2514 rows x 3 columns]>

# %%
#graph to visualuze mean returns for ETFs
equal_weight_corr = returns.mean()
plt.figure(figsize=(8, 4))
plt.bar(equal_weight_corr.index, equal_weight_corr.values, color='skyblue')

plt.title('Mean Returns for ETFs', fontsize=14)
plt.xlabel('ETF Ticker', fontsize=12)
plt.ylabel('Mean Return', fontsize=12)

plt.show()

# %%
#concat the dataframes for a combined correlation matrix
combined_portfolio = pd.concat([risk_analysis, portfolio_risk], axis=1)
combined_portfolio
# Out:
#        Ticker  Portfolio Weight  Annualized Volatility  Beta Against SPY  \
# Ticker
# BA         BA          0.142857             177.788679               NaN
# CVS       CVS          0.142857              22.344108               NaN
# DIS       DIS          0.142857              60.565141               NaN
# JNJ       JNJ          0.142857             103.624492               NaN
# KO         KO          0.142857              50.888852               NaN
# T           T          0.142857              17.391015               NaN
# UPS       UPS          0.142857              93.798928               NaN
# SPY       NaN               NaN                    NaN               NaN
# IWM       NaN               NaN                    NaN               NaN
# HDV       NaN               NaN                    NaN               NaN
#
#         Beta Against IWM  Beta Against DIA  Average Weekly Drawdown  \
# Ticker
# BA                   NaN               NaN                 0.189717
# ...

# %%
# Check which columns contain non-numeric values
non_numeric_columns = combined_portfolio.select_dtypes(exclude=[float, int]).columns
non_numeric_columns
# Out:
# Index(['Ticker', 'ETF Ticker'], dtype='object')

# %%
#drop non-numeric columns
combined_portfolio_numeric = combined_portfolio.drop(columns=['Ticker', 'ETF Ticker'])

# %%
#create the correlation matrix
correlation_matrix = combined_portfolio_numeric.corr()
correlation_matrix
# Out:
#                               Portfolio Weight  Annualized Volatility  \
# Portfolio Weight                           NaN                    NaN
# Annualized Volatility                      NaN               1.000000
# Beta Against SPY                           NaN                    NaN
# Beta Against IWM                           NaN                    NaN
# Beta Against DIA                           NaN                    NaN
# Average Weekly Drawdown                    NaN               0.744423
# Maximum Weekly Drawdown                    NaN               0.078187
# Total Return                               NaN               0.414479
# Annualized Total Return                    NaN               0.481195
# Correlation Against ETF                    NaN                    NaN
# Covariance Against ETF                     NaN                    NaN
# Standard Deviation ETF                     NaN                    NaN
# ...

# %%
#plot/visualize the final correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix between Portfolios and ETFs', fontsize=14)
plt.xlabel('Portfolios and ETFs', fontsize=12)
plt.ylabel('Portfolios and ETFs', fontsize=12)
plt.show()
